# %% [markdown]
# #Heart Disease Analysis

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df.tail()
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 1185                    0            0             132                0
# 1186                    1            0             141                0
# 1187                    0            0             115                1
# 1188                    0            2             174                0
# 1189                    0            0             173                0
#
#       oldpeak  ST slope  target
# 1185      1.2         2       1
# 1186      3.4         2       1
# 1187      1.2         2       1
# 1188      0.0         2       1
# ...

# %%
df.shape
# Out:
# (1190, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB

# %%
df.isnull().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %%
dp_val = df.duplicated().any()
print(dp_val)
# Out:
# True

# %%
df =df.drop_duplicates()
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.corr()
# Out:
#                           age       sex  chest pain type  resting bp s  \
# age                  1.000000  0.055750         0.165896      0.254399
# sex                  0.055750  1.000000         0.168254      0.005133
# chest pain type      0.165896  0.168254         1.000000      0.022168
# resting bp s         0.254399  0.005133         0.022168      1.000000
# cholesterol         -0.095282 -0.200092        -0.136139      0.100893
# fasting blood sugar  0.198039  0.120076         0.116703      0.070193
# resting ecg          0.213152 -0.018343         0.031383      0.097661
# max heart rate      -0.382045 -0.189186        -0.343654     -0.112135
# exercise angina      0.215793  0.190664         0.416625      0.155101
# oldpeak              0.258612  0.105734         0.245027      0.164803
# ST slope             0.261760  0.148282         0.317256      0.071477
# target               0.282039  0.305445         0.471354      0.107589
#
# ...

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# #Numbers Affected and Unaffected by Heart problems

# %%
df.columns
# Out:
# Index(['age', 'sex', 'chest pain type', 'resting bp s', 'cholesterol',
#        'fasting blood sugar', 'resting ecg', 'max heart rate',
#        'exercise angina', 'oldpeak', 'ST slope', 'target'],
#       dtype='object')

# %%
sns.countplot(x='target', hue='target', data=df, palette="Set1", legend=False)
plt.show()

# %% [markdown]
# #gender distribution in dataset

# %%
df.columns
# Out:
# Index(['age', 'sex', 'chest pain type', 'resting bp s', 'cholesterol',
#        'fasting blood sugar', 'resting ecg', 'max heart rate',
#        'exercise angina', 'oldpeak', 'ST slope', 'target'],
#       dtype='object')

# %%
sns.countplot(x='sex', hue='sex', data=df, palette="Set1", legend=C)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# #distribution of heart disease amoung males and females

# %%
sns.countplot(data=df,x=df['sex'],hue=df['target'])
plt.xticks([0,1],['Female','Male'])
plt.legend(labels=['No disease','disease'])
plt.show()

# %% [markdown]
# #Distribution of ages in our dataset

# %%
sns.distplot(df['age'],bins=20)
plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_16012\1602346454.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],bins=20)

# %% [markdown]
# #Chest pain types

# %%
sns.countplot(x='chest pain type', data=df,palette="Set1",legend=False)
plt.xticks([0, 1, 2, 3], ['Typical angina', 'Atypical angina', 'Non-anginal pain', 'Asymptomatic'])

plt.show()
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_16012\302996867.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='chest pain type', data=df,palette="Set1",legend=False)

# %% [markdown]
# #chest pain distribution in heart disease vs non heart disease

# %%
sns.countplot(x='chest pain type', hue='target', data=df, palette="Set1")

plt.xticks([0, 1, 2, 3], ['Typical angina', 'Atypical angina', 'Non-anginal pain', 'Asymptomatic'])
plt.xlabel("Chest Pain Type")
plt.ylabel("Count")
plt.legend(title="Heart Disease", labels=["No Disease", "Disease"])
plt.title("Chest Pain Distribution: Heart Disease vs Non-Heart Disease")

plt.show()

# %% [markdown]
# #resting blood pressure distribution overview

# %%
sns.histplot(df['resting bp s'], bins=30, kde=True, color="skyblue")
plt.xlabel("Resting Blood Pressure (mm Hg)")
plt.ylabel("Count")
plt.title("Distribution of Resting Blood Pressure")
plt.show()

# %% [markdown]
# #serum cholestroldata distribution

# %%
df['cholesterol'].hist(bins=30, color="skyblue")
plt.xlabel("Cholesterol (mg/dl)")
plt.ylabel("Count")
plt.title("Cholesterol Distribution")
plt.show()
